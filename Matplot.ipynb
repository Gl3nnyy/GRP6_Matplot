# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Americano", "Caramel Macchiato", "Cappuccino", "Frappé"])
y = np.array([120, 163, 213, 154])

plt.bar(x,y)
plt.title("Coffee sales")
plt.xlabel("Coffee")
plt.ylabel("Sales")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday","Sunday"])
y = np.array([72, 57, 54, 34, 65, 42, 59 ])

plt.plot(x, y, marker = 'o')
plt.title("Black Americano sales")
plt.ylabel("Sales")
plt.show()
